# %% [markdown]
# Day 1 of learning Matplotlib-  Part-1

# %%
# importing matplotlib
import matplotlib.pyplot as plt

# Basic structure using matplotlib
x = [1,2,3,4,5]
y = [2,3,6,8,10]

plt.plot(x,y)
plt.xlabel("X-axis (x marks)")
plt.ylabel("Y-axid (y marks)")
plt.title("X and Y values")
plt.grid(True)                  # This will show the grid in graph
plt.show()

# %%
# Styling a Line Plot

x = [1,2,3,4,5]
y = [5,6,9,8,7]

plt.plot(x,y,
         color = "blue",
         linestyle = "--",
         linewidth = "2",
         marker = "o",
         markersize = 6
         )

plt.xlabel("Years")
plt.ylabel("Values")
plt.title("Values and Years")
plt.grid(True)
plt.show()

# %%
# Multiple lines on the same plot

x = [1,2,3,4,5]
y = [5,6,9,8,7]
y2 = [1,5,10,6,8]

plt.plot(x,y, label = "line1")
plt.plot(x,y2, label = "line2")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Multi lines on same plot")
plt.legend()                         # Give the name to the lines
plt.show()

# %%
# Saving the plots

# plt.savefig("line-plot.png")    # Code to save the plot in png format

# %%
# Bat chat
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,9,6,8,10]

plt.bar(x,y)
plt.xlabel("x axis label")
plt.ylabel("y axis label")
plt.title("Bar graph")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Styling a Bar Chart

x = [1,2,3,4,5]
y = [2,9,6,8,10]

plt.bar(x,y,
         color = "skyblue",
         linewidth = 1.5,
         edgecolor = "black",
         width = 0.6 
         )

plt.text(3,6, "Hello")       # It take a argument a first x and sencond y and with double inverted comma where we placa a string or data
plt.show()

# %%
# Horizontal Bar Chat

x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.barh(x,y)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Horizontal Bar Graph")
plt.grid(True)
plt.show()

# %%
# Multiple Grouped Baar Charts (Grouped Bars)

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(4)
y1 = [10,15,7,12]
y2 = [8,14,9,10]

width = 0.35

plt.bar(x - width/2,y1,width,label = "Group1")
plt.bar(x + width/2,y2,width,label = "Group2")

plt.xticks(x,["A","B","C","D"])
plt.xlabel("Catogeries")
plt.ylabel("Values")
plt.legend()
plt.show()

# %%
# pracrtise
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [2,4,6,8]

plt.plot(x, y,
         color = "red"
         )
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Title")
plt.grid(True)
# plt.legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28628\2157792204.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Multiple lines on same plot
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,8,5,3,7]
y2 =[2,4,6,8,9]

plt.plot(x,y, label = "liens 1")
plt.plot(x,y2, label = "lines 2")
plt.xlabel('x values')
plt.ylabel('y values')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Styling a bar chart
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,8,5,3,7]

plt.bar(x, y, 
        color = "skyblue",
        width = 0.6,
        edgecolor = "black",
        linewidth = 1.5
        )

plt.text(x[0],y[0],"Text")
plt.show()

# %%
# Scatter plots
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6,7,7]
y = [2,3,4,3,3,5,4,1]

plt.scatter(x, y)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Scatter Plots")
plt.grid(True)
plt.show()

# %%
# Using a colormap (color by values)
import numpy as np
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,8,5,3,7]
 
colors = np.array([10,20,30,40,50])

plt.scatter(x, y, c = colors, cmap = "viridis")
plt.colorbar(label = "color scale")
plt.show()

# %%
# Multiple scattert plots
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6,7,8,9]
y = [1,1,2,3,3,4,5,5,4]
y2 = [6,6,7,7,8,8,8,9,9]

plt.scatter(x, y, label = "set1")
plt.scatter(x, y2, label = "set2")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
